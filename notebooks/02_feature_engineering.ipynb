# %% [markdown]
# # Feature Engineering for IAM Analysis
#
# Create ML-ready features from raw IAM logs.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src.data.preprocessors import IAMDataPreprocessor
from src.data.feature_extractors import IAMFeatureExtractor
import pandas as pd

# Load data
df = pd.read_csv('../data/sample_iam_logs.csv')

# Preprocess
preprocessor = IAMDataPreprocessor()
df = preprocessor.preprocess_for_training(df)

print(f"Dataset shape: {df.shape}")
print(f"Feature columns: {preprocessor.get_feature_columns()}")
